# %%
print("Hello, World")
# Out:
# Hello, World

# %%
import sys
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]

# %%
print("i ma learning python for AI")
print("i love it.")
# Out:
# i ma learning python for AI
# i love it.

# %%
print("i ma learning python for AI")
exit()
# Out:
# i ma learning python for AI

# %%
#Python indentation
#use the same number of spaces in the same block of code, otherwise Python will give you an error:

if 10>2:
    print("ten is greater than two ")
else:
    print("two is not greater than 10")
# Out:
# ten is greater than two

# %%
#python variables
# variable is created when you assign a value to it
x= 120
y= "hello, python"
print(x)
print(y)
# Out:
# 120
# hello, python
