# %%
# Python Data Types
# Variables can store data of different types, and different types can do different things.
# Text Type:	str
# Numeric Types:	int, float, complex
# Sequence Types:	list, tuple, range
# Mapping Type:	dict
# Set Types:	set, frozenset
# Boolean Type:	bool
# Binary Types:	bytes, bytearray, memoryview
# None Type:	NoneType

# %%
x = "Hello World"
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>

# %%
x = 10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
x = 3.4
print(x)
print(type(x))
# Out:
# 3.4
# <class 'float'>

# %%
x = 3+4j
print(x)
print(type(x))
# Out:
# (3+4j)
# <class 'complex'>

# %%
x = ["apple","banana"]
print(x)
print(type(x))
# Out:
# ['apple', 'banana']
# <class 'list'>

# %%
x = ("apple","banana")
print(x)
print(type(x))
# Out:
# ('apple', 'banana')
# <class 'tuple'>

# %%
x = {"apple","banana"}
print(x)
print(type(x))
# Out:
# {'banana', 'apple'}
# <class 'set'>

# %%
x = range(8)
print(x)
print(type(x))
# Out:
# range(0, 8)
# <class 'range'>

# %%
x = {"name" : " python", "age" : 45}
print(x)
print(type(x))
# Out:
# {'name': ' python', 'age': 45}
# <class 'dict'>

# %%
x = frozenset({"apple","banana"})
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'apple'})
# <class 'frozenset'>

# %%
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
x = b"hello"
print(x)
print(type(x))
# Out:
# b'hello'
# <class 'bytes'>

# %%
x = bytearray(6)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(x)
print(type(x))
# Out:
# <memory at 0x10881f100>
# <class 'memoryview'>

# %%
x = None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %%
# python number
# there are three numeric types in poython
x = 4 # int 
y = 4.5 # float
z=3j  # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
# Type Conversion
# You can convert from one type to another with the int(), float(), and complex() methods:

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
# Random Number
# Python does not have a random() function to make a random number, but Python has a built-in module called random that can be used to make random numbers:

# %%
import random
print(random.randrange(1,100))
# Out:
# 84

# %%
# Python Casting
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3
